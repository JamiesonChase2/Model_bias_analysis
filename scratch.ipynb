# %% [markdown]
# # Scratch

# %% [markdown]
# ## Token count
# Q: How many tokens does this word split into?  A: 2
#
# Requires the transformers package and also agreeing to Kaggle's HuggingFace license terms before downloading

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("google/gemma-2-2b")
tokenizer.tokenize("chevronné")
